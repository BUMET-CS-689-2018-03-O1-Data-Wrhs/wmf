# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import pandas as pd
pd.options.display.mpl_style = 'default'

import inspect, os
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
os.sys.path.insert(0,parentdir) 
from src.dashboard_helpers import Test, custom_amount_stats
from src.data_retrieval import *
# Out:
# Vendor:  Continuum Analytics, Inc.
# Package: mkl
# Message: trial mode expires in 30 days

# %%
a = 'B1516_0826_en6C_dsk_p1_lg_cntrl'
b = 'B1516_0826_en6C_dsk_p1_lg_2step'
c = 'B1516_0826_en6C_dsk_p1_lg_450ml'
d = 'B1516_0826_en6C_dsk_p1_lg_pplbg'
e = 'B1516_0826_en6C_dsk_p1_lg_sustn'
f = 'B1516_0826_en6C_dsk_p1_lg_vlntr'


start = '2015-08-26 00'
stop = '2015-08-27 00'

t = Test(a, b,c, d, e, f, start = start, stop = stop)

# %%
t_hive = Test(a, b,c, d, e, f, start = start, stop = stop, hive = True,)

# %%
t.ecom()
# Out:
#                        B1516_0826_en6C_dsk_p1_lg_2step  \
# donations                                         1340
# recurring donations                                  0
# impressions                                     148700
# dons/i                                         0.00901
# amount                                           12756
# amount/i                                       0.08578
# clicks                                            1972
# clicks/i                                       0.01326
# dons/clicks                                    0.67951
# amount (no outliers)                             11114
# amount/i (no outliers)                         0.07475
# max                                                250
# median                                            5.00
# avg                                               9.52
# avg (no outliers)                                 8.39
#
#                        B1516_0826_en6C_dsk_p1_lg_450ml  \
# ...

# %%
t_hive.ecom()
# Out:
#                        B1516_0826_en6C_dsk_p1_lg_2step  \
# donations                                         1340
# recurring donations                                  0
# impressions                                     168830
# dons/i                                         0.00794
# amount                                           12756
# amount/i                                       0.07556
# clicks                                            1972
# clicks/i                                       0.01168
# dons/clicks                                    0.67951
# amount (no outliers)                             11114
# amount/i (no outliers)                         0.06583
# max                                                250
# median                                            5.00
# avg                                               9.52
# avg (no outliers)                                 8.39
#
#                        B1516_0826_en6C_dsk_p1_lg_450ml  \
# ...

# %%
t.rate_stats( conf = 95, rate = 'donations/impressions')
# Out:
#                                  P(Winner)      Winners Lift  \
# B1516_0826_en6C_dsk_p1_lg_pplbg          1    (0.00%, 0.00%)
# B1516_0826_en6C_dsk_p1_lg_2step        NaN  (18.87%, 37.14%)
# B1516_0826_en6C_dsk_p1_lg_450ml        NaN  (11.89%, 28.57%)
# B1516_0826_en6C_dsk_p1_lg_cntrl        NaN  (15.69%, 33.25%)
# B1516_0826_en6C_dsk_p1_lg_sustn        NaN  (16.84%, 34.47%)
# B1516_0826_en6C_dsk_p1_lg_vlntr        NaN  (28.56%, 48.40%)
#
#                                                    CI
# B1516_0826_en6C_dsk_p1_lg_pplbg  (0.010975, 0.012060)
# B1516_0826_en6C_dsk_p1_lg_2step  (0.008542, 0.009502)
# B1516_0826_en6C_dsk_p1_lg_450ml  (0.009117, 0.010098)
# B1516_0826_en6C_dsk_p1_lg_cntrl  (0.008789, 0.009766)
# B1516_0826_en6C_dsk_p1_lg_sustn  (0.008706, 0.009674)
# B1516_0826_en6C_dsk_p1_lg_vlntr  (0.007892, 0.008796)

# %%
t_hive.rate_stats( conf = 90, rate = 'donations/impressions')
# Out:
#                                  P(Winner)      Winners Lift  \
# B1516_0826_en6C_dsk_p1_lg_pplbg    0.99998    (0.00%, 0.00%)
# B1516_0826_en6C_dsk_p1_lg_450ml    0.00002   (9.48%, 22.90%)
# B1516_0826_en6C_dsk_p1_lg_2step        NaN  (19.29%, 34.36%)
# B1516_0826_en6C_dsk_p1_lg_cntrl        NaN  (16.67%, 31.39%)
# B1516_0826_en6C_dsk_p1_lg_sustn        NaN  (15.76%, 30.34%)
# B1516_0826_en6C_dsk_p1_lg_vlntr        NaN  (24.15%, 40.17%)
#
#                                                    CI
# B1516_0826_en6C_dsk_p1_lg_pplbg  (0.009660, 0.010454)
# B1516_0826_en6C_dsk_p1_lg_450ml  (0.008301, 0.009041)
# B1516_0826_en6C_dsk_p1_lg_2step  (0.007590, 0.008299)
# B1516_0826_en6C_dsk_p1_lg_cntrl  (0.007764, 0.008484)
# B1516_0826_en6C_dsk_p1_lg_sustn  (0.007828, 0.008549)
# B1516_0826_en6C_dsk_p1_lg_vlntr  (0.007279, 0.007975)

# %%
t.rate_stats( c, d, conf = 90, rate = 'donations/impressions')
# Out:
#                                  P(Winner)      Winners Lift  \
# B1516_0826_en6C_dsk_p1_lg_pplbg          1    (0.00%, 0.00%)
# B1516_0826_en6C_dsk_p1_lg_450ml        NaN  (13.11%, 27.17%)
#
#                                                    CI
# B1516_0826_en6C_dsk_p1_lg_pplbg  (0.011057, 0.011970)
# B1516_0826_en6C_dsk_p1_lg_450ml  (0.009193, 0.010014)

# %%
t_hive.rate_stats( c, d, conf = 90, rate = 'donations/impressions')
# Out:
#                                  P(Winner)     Winners Lift  \
# B1516_0826_en6C_dsk_p1_lg_pplbg    0.99998   (0.00%, 0.00%)
# B1516_0826_en6C_dsk_p1_lg_450ml    0.00002  (9.42%, 22.99%)
#
#                                                    CI
# B1516_0826_en6C_dsk_p1_lg_pplbg  (0.009657, 0.010454)
# B1516_0826_en6C_dsk_p1_lg_450ml  (0.008303, 0.009041)
