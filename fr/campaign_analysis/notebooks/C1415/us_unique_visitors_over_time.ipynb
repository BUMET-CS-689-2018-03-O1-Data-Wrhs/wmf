# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import matplotlib.pyplot as plt
pd.options.display.mpl_style = 'default'

from campaign_analysis import *

# %%
start = '2014-11-28 00:00'
stop = '2015-01-03 08:00'

imp = get_impressions(start, stop, country_id = 1)

# %%
import collections

regs = collections.OrderedDict()
regs['Large Desk'] =  '.*5C_lg.* C14_en5C_dec_dsk_FR'
regs['Large Mobile'] = '.*_lg.* C14_en5C_dec_mob_FR'
regs['Large Ipad'] = '.*_lg.* C14_en5C_dec_ipd_FR'

# %%
config = {
            'hours' :24, 
            'stop': '2015-01-01 00',
            'ylabel': 'fraction of unique visitors',
            'cum': True,
            'normalize' : True,
            'rotate': True
        }

plot_by_time(imp, regs, **config)

# %% [markdown]
# The above plot shows what fraction of December's unique visitors visited the site at least once for each day. The data is broken down by device type.

# %%
config = {
            'hours' :24, 
            'stop': '2015-01-01 00',
            'ylabel': 'number of unique visitors',
            'cum': True,
            'rotate': True
        }

plot_by_time(imp, regs, **config)
