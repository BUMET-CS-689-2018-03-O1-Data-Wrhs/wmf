# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import matplotlib.pyplot as plt
pd.options.display.mpl_style = 'default'

from campaign_analysis import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
start = '2014-11-28 00:00'
stop = '2015-01-03 08:00'

imp = get_impressions(start, stop, country_id = 1)

# %%
imp['weekday'] = imp.index.weekday
imp['hour'] = (imp.index.hour + 16) % 24

# %%
desk_regs = {
    'Large Desk': '.*5C_lg.* C14_en5C_dec_dsk_FR',
    'Top Desk': '.*5C_tp.* C14_en5C_dec_dsk_FR',
}

# %%
mob_regs = {
    'Large Mobile': '.*_lg.* C14_en5C_dec_mob_FR',
    'Top Mobile': '.*_tp.* C14_en5C_dec_mob_FR'
}

ipd_regs = {
    'Large Ipad': '.*_lg.* C14_en5C_dec_ipd_FR',
    'Top Ipad': '.*_tp.* C14_en5C_dec_ipd_FR'
}

# %%
config = {
            'hours' :1, 
            'stop': '2015-01-01 00',
            'ylabel': 'impressions per hour'
        }

plot_by_time(imp, desk_regs, **config)

# %% [markdown]
# #Weekly Impressions: US Desktop

# %%
config = {
            'start' : '2014-12-01 00:00',
            'stop' : '2014-12-08 000:00',
            'ylabel': 'impressions per hour',
            'hours': 1
}

plot_by_time(imp, {'All': '.* C14_en5C_dec_dsk_FR'}, **config )
plot_by_time(imp, {'Large Desk': '.*5C_lg.* C14_en5C_dec_dsk_FR'}, **config )
#plot_by_time(imp, {'Top Desk': '.*5C_tp.* C14_en5C_dec_dsk_FR'}, **config )

# %% [markdown]
# "All" refers to any banner impression (proxy for pageviews when the campaign is at 100%). "Large Desk" refers to impressions of the Full screen banner, which was only show once per user. You can think of this being the number of people visiting for first time since Dec 2. There is not quite, a full week, but it looks like impressions fall over the course of the week, reahing a low point on Saturday. Lets look at another week:

# %%
config = {
            'start' : '2014-12-08 00:00',
            'stop' : '2014-12-15 000:00',
            'ylabel': 'impressions per hour',
            'hours': 1
}

plot_by_time(imp, {'All': '.* C14_en5C_dec_dsk_FR'}, **config )
plot_by_time(imp, {'Large Desk': '.*5C_lg.* C14_en5C_dec_dsk_FR'}, **config )
#plot_by_time(imp, {'Top Desk': '.*5C_tp.* C14_en5C_dec_dsk_FR'}, **config

# %% [markdown]
# Same pattern Lets look at hourly trends:

# %%
config = {
            'start' : '2014-12-01 00:00',
            'stop' : '2014-12-15 000:00',
            'ylabel': 'impressions by hour of day',
            'index': 'hour'
}

plot_by_time(imp, {'All': '.* C14_en5C_dec_dsk_FR'}, **config )
plot_by_time(imp, {'Large Desk': '.*5C_lg.* C14_en5C_dec_dsk_FR'}, **config )

# %% [markdown]
# Activity peeks at 12 PST, dips until 16 PST, remains flat until 18 PST and then falls. This data is for all US, so be carefull about interpretation!!

# %% [markdown]
# #Weekly Impression Numbers: US Mobile

# %%
config = {
            'hours' :1, 
            'stop': '2015-01-01 00',
            'ylabel': 'impressions per hour',

        }

plot_by_time(imp, mob_regs, **config)

# %%
config = {
            'start' : '2014-12-08 00:00',
            'stop' : '2014-12-15 00:00',
            'ylabel': 'impressions per hour',
            'hours': 1
}

plot_by_time(imp, {'All Mob': '.* C14_en5C_dec_mob_FR'}, **config )
plot_by_time(imp, {'Large Mob': '.*_lg.* C14_en5C_dec_mob_FR'}, **config )
#plot_by_time(imp, {'Top Mob': '.*_tp.* C14_en5C_dec_mob_FR'}, **config )

# %% [markdown]
# The first week is truncated, lets look at the second

# %%
config = {
            'start' : '2014-12-15 00:00',
            'stop' : '2014-12-22 00:00',
            'ylabel': 'impresisons per hour',
            'hours': 1
}

plot_by_time(imp, {'All Mob': '.* C14_en5C_dec_mob_FR'}, **config )
plot_by_time(imp, {'Large Mob': '.*_lg.* C14_en5C_dec_mob_FR'}, **config )
#plot_by_time(imp, {'Top Mob': '.*_tp.* C14_en5C_dec_mob_FR'}, **config )

# %% [markdown]
# Drop from Sunday to Friday. Increase from Friday to Sunday. Neat that impressions and fist time visits are so well correlated. Lets look at hourly patterns.

# %%
config = {
            'start' : '2014-12-15 00:00',
            'stop' : '2014-12-22 000:00',
            'ylabel': 'impressions by hour of day',
            'index': 'hour'
}
plot_by_time(imp, {'All Mob': '.* C14_en5C_dec_mob_FR'}, **config )
plot_by_time(imp, {'Large Mob': '.*_lg.* C14_en5C_dec_mob_FR'}, **config )

# %% [markdown]
# Neat that impressions and fist time visits are so well correlated! Mobile views peek from 15-19 PST. Post work usage?
